# %%
#Importing Libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('ElectionData.csv')
df
# Out:
#        TimeElapsed              time        territoryName  totalMandates  \
# 0                0  06-10-2019 20:10  Território Nacional              0
# 1                0  06-10-2019 20:10  Território Nacional              0
# 2                0  06-10-2019 20:10  Território Nacional              0
# 3                0  06-10-2019 20:10  Território Nacional              0
# 4                0  06-10-2019 20:10  Território Nacional              0
# ...            ...               ...                  ...            ...
# 21638          265  07-10-2019 00:35                Viseu              8
# 21639          265  07-10-2019 00:35                Viseu              8
# 21640          265  07-10-2019 00:35                Viseu              8
# 21641          265  07-10-2019 00:35                Viseu              8
# 21642          265  07-10-2019 00:35                Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    TimeElapsed              time        territoryName  totalMandates  \
# 0            0  06-10-2019 20:10  Território Nacional              0
# 1            0  06-10-2019 20:10  Território Nacional              0
# 2            0  06-10-2019 20:10  Território Nacional              0
# 3            0  06-10-2019 20:10  Território Nacional              0
# 4            0  06-10-2019 20:10  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  nullVotesPercentage  votersPercentage  \
# ...

# %%
#checking the datatype of each column 
print(df.dtypes)
# All features are of integer type
print(df.info())
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# ...

# %%
df.shape
# Out:
# (21643, 28)

# %%
#checking null values using heat map
sns.heatmap(df.isnull())
#we can see that their is no null values

# %%
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['time']).dt.date
df['Time'] = pd.to_datetime(df['time']).dt.time

# %%
df.head()
# Out:
#    TimeElapsed              time        territoryName  totalMandates  \
# 0            0  06-10-2019 20:10  Território Nacional              0
# 1            0  06-10-2019 20:10  Território Nacional              0
# 2            0  06-10-2019 20:10  Território Nacional              0
# 3            0  06-10-2019 20:10  Território Nacional              0
# 4            0  06-10-2019 20:10  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  nullVotesPercentage  votersPercentage  \
# ...

# %%
df.drop(['time'],axis=1,inplace=True)

# %%
df["Year"] = pd.to_datetime(df.Dates, format="%Y-%d-%m").dt.year

# %%
df["Days"] = pd.to_datetime(df.Dates, format="%Y-%d-%m").dt.day

# %%
df["Months"] = pd.to_datetime(df.Dates, format="%Y-%d-%m").dt.month

# %%
df.head()
# Out:
#    TimeElapsed        territoryName  totalMandates  availableMandates  \
# 0            0  Território Nacional              0                226
# 1            0  Território Nacional              0                226
# 2            0  Território Nacional              0                226
# 3            0  Território Nacional              0                226
# 4            0  Território Nacional              0                226
#
#    numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 0         3092                 1081        9652                   2.5
# 1         3092                 1081        9652                   2.5
# 2         3092                 1081        9652                   2.5
# 3         3092                 1081        9652                   2.5
# 4         3092                 1081        9652                   2.5
#
#    nullVotes  nullVotesPercentage  votersPercentage  subscribedVoters  \
# ...

# %%
df['Months'].value_counts()
# Out:
# 10    21643
# Name: Months, dtype: int64

# %%
df['Days'].value_counts()
# Out:
# 6    18419
# 7     3224
# Name: Days, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# 2019    21643
# Name: Year, dtype: int64

# %%
df.drop(['Dates'],axis=1,inplace=True)

# %%
df['Time'].value_counts()
# Out:
# 23:35:00    403
# 00:05:00    403
# 22:15:00    403
# 21:20:00    403
# 22:10:00    403
# 23:30:00    403
# 22:35:00    403
# 22:45:00    403
# 21:00:00    403
# 22:20:00    403
# 23:50:00    403
# 21:30:00    403
# 20:55:00    403
# 21:50:00    403
# 22:50:00    403
# 20:50:00    403
# 00:35:00    403
# 00:25:00    403
# 21:15:00    403
# 21:05:00    403
# 23:40:00    403
# 20:45:00    403
# 23:45:00    403
# 00:00:00    403
# 22:30:00    403
# 21:10:00    403
# 00:20:00    403
# 23:00:00    403
# 23:10:00    403
# 23:15:00    403
# 23:20:00    403
# 23:05:00    403
# 22:40:00    403
# 23:25:00    403
# 22:00:00    403
# 21:45:00    403
# 22:55:00    403
# 21:55:00    403
# 21:25:00    403
# 23:55:00    403
# 00:30:00    403
# 00:15:00    403
# 21:40:00    403
# 22:05:00    403
# 22:25:00    403
# 00:10:00    403
# 21:35:00    403
# 20:20:00    386
# 20:35:00    386
# 20:40:00    386
# 20:10:00    386
# 20:25:00    386
# 20:15:00    386
# 20:30:00    386
# Name: Time, dtype: int64

# %%
# Encoding Time as an ordinal variable r
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Time_encoded']=pd.DataFrame(le.fit_transform(df.Time))

# %% [markdown]
# # Data Analysis Through Visualization

# %%
plt.subplots(figsize=(15,15))
sns.countplot(df['Party'])

# %%
plt.violinplot(df["numParishes"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2969f68e220>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2969f68e070>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2969f68e0a0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2969f68e670>}

# %%
plt.violinplot(df["subscribedVoters"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2969fecf820>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2969fecf670>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2969fecf6a0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2969fecfc70>}

# %%
plt.figure(figsize=(10,10))
x = df.subscribedVoters.value_counts()[:15]
y = df['subscribedVoters'].value_counts()[:15].index
plt.pie(x, labels=y, autopct='%.2f')
plt.title('Distribution of subscribed Voters in Portugal Election')
plt.show()

# %%
plt.figure(figsize=(10,10))
x = df.territoryName.value_counts()[:15]
y = df['territoryName'].value_counts()[:15].index
plt.pie(x, labels=y, autopct='%.2f')
plt.title('Distribution of Territories in Portugal Election')
plt.show()

# %%
plt.figure(figsize=(10,10))
x = df.totalMandates.value_counts()[:15]
y = df['totalMandates'].value_counts()[:15].index
plt.pie(x, labels=y, autopct='%.2f')
plt.title('Distribution of Total Mandates in Portugal Election')
plt.show()

# %%
plt.figure(figsize=(10,10))
x = df.availableMandates.value_counts()[:15]
y = df['availableMandates'].value_counts()[:15].index
plt.pie(x, labels=y, autopct='%.2f')
plt.title('Distribution of Available Mandates in Portugal Election')
plt.show()

# %%
sns.catplot(y = "totalMandates", x = "Party", data = df.sort_values("totalMandates", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "availableMandates", x = "Party", data = df.sort_values("availableMandates", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "FinalMandates", x = "Party", data = df.sort_values("FinalMandates", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "pre.nullVotes", x = "Party", data = df.sort_values("pre.nullVotes", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(4,8),figsize=(20,20))
# Out:
# TimeElapsed                     AxesSubplot(0.125,0.71587;0.0824468x0.16413)
# totalMandates                AxesSubplot(0.223936,0.71587;0.0824468x0.16413)
# availableMandates            AxesSubplot(0.322872,0.71587;0.0824468x0.16413)
# numParishes                  AxesSubplot(0.421809,0.71587;0.0824468x0.16413)
# numParishesApproved          AxesSubplot(0.520745,0.71587;0.0824468x0.16413)
# blankVotes                   AxesSubplot(0.619681,0.71587;0.0824468x0.16413)
# blankVotesPercentage         AxesSubplot(0.718617,0.71587;0.0824468x0.16413)
# nullVotes                    AxesSubplot(0.817553,0.71587;0.0824468x0.16413)
# nullVotesPercentage            AxesSubplot(0.125,0.518913;0.0824468x0.16413)
# votersPercentage            AxesSubplot(0.223936,0.518913;0.0824468x0.16413)
# subscribedVoters            AxesSubplot(0.322872,0.518913;0.0824468x0.16413)
# totalVoters                 AxesSubplot(0.421809,0.518913;0.0824468x0.16413)
# ...

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#         TimeElapsed  totalMandates  availableMandates   numParishes  \
# count  21643.000000   21643.000000       21643.000000  21643.000000
# mean     133.146052      11.544795          11.499284    309.956013
# std       77.651193      31.314567          31.738783    659.055911
# min        0.000000       0.000000           0.000000     54.000000
# 25%       65.000000       1.000000           0.000000     75.000000
# 50%      135.000000       4.000000           3.000000    147.000000
# 75%      200.000000       9.000000           9.000000    242.000000
# max      265.000000     226.000000         226.000000   3092.000000
#
#        numParishesApproved     blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000   21643.000000          21643.000000  21643.000000
# mean            261.090237    8875.066673              2.621629   6148.068752
# std             583.377428   21484.874088              0.795289  14735.469269
# ...

# %% [markdown]
#  -> From the above analysis we can see that their is adiff between Q3(75%) and maximun in total mandates, available mandates
# numParishes,numParishes Approved, blank votes , null votes,Pre blank votes, pre null votes, hondt...So after seeing this we can say that their are lots of outliers present in the data set

# %%
#Observing corelation between the columns through heatmap
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.corr()
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.260377          -0.261627
# totalMandates                0.260377       1.000000           0.217404
# availableMandates           -0.261627       0.217404           1.000000
# numParishes                 -0.001944       0.765877           0.745472
# numParishesApproved          0.100432       0.873415           0.562719
# blankVotes                   0.192350       0.969988           0.390638
# blankVotesPercentage         0.034343      -0.003149          -0.002806
# nullVotes                    0.185784       0.967294           0.407366
# nullVotesPercentage         -0.225021      -0.165132           0.029915
# votersPercentage             0.029698       0.171317           0.112293
# subscribedVoters             0.195487       0.974407           0.385828
# totalVoters                  0.198243       0.976336           0.379093
# ...

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# ...

# %%
df
# Out:
#        TimeElapsed        territoryName  totalMandates  availableMandates  \
# 0                0  Território Nacional              0                226
# 1                0  Território Nacional              0                226
# 2                0  Território Nacional              0                226
# 3                0  Território Nacional              0                226
# 4                0  Território Nacional              0                226
# ...            ...                  ...            ...                ...
# 21638          265                Viseu              8                  0
# 21639          265                Viseu              8                  0
# 21640          265                Viseu              8                  0
# 21641          265                Viseu              8                  0
# 21642          265                Viseu              8                  0
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# ...

# %%
df.drop(columns=["Time"],inplace=True)

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['territoryName','Party']
for i in list1:
    df[i]=le.fit_transform(df[i].astype(str))

# %% [markdown]
# # Removing Outliers

# %%
for i in df.columns:
    if df.skew().loc[i]>0.55:
        df[i]=np.log1p(df[i])

# %%
df.skew()
# Out:
# TimeElapsed                -0.005496
# territoryName              -0.025884
# totalMandates               0.673353
# availableMandates           0.739482
# numParishes                 1.724389
# numParishesApproved         0.363008
# blankVotes                 -0.132151
# blankVotesPercentage        0.069627
# nullVotes                  -0.033397
# nullVotesPercentage         0.545046
# votersPercentage           -1.158029
# subscribedVoters            0.019051
# totalVoters                 0.091477
# pre.blankVotes             -0.043120
# pre.blankVotesPercentage    0.021609
# pre.nullVotes              -0.019415
# pre.nullVotesPercentage     0.786357
# pre.votersPercentage       -0.779289
# pre.subscribedVoters        0.021921
# pre.totalVoters             0.094050
# Party                      -0.083536
# Mandates                    4.368206
# Percentage                  1.416849
# validVotesPercentage        1.404150
# Votes                       0.367201
# ...

# %% [markdown]
# # Splitting the data into input and target

# %%
x=df.drop('FinalMandates',axis=1)
y=df['FinalMandates']

# %%
print(x.shape)
print(y.shape)
# Out:
# (21643, 30)
# (21643,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (21643, 1)

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(x, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [1.24929156e-04 2.02251040e-03 2.63190161e-04 3.07679418e-03
#  1.19111977e-02 4.18990497e-03 2.96811603e-04 3.32362364e-04
#  2.76911906e-03 2.99676353e-04 7.06218684e-04 2.20113268e-03
#  1.76911522e-03 6.53147793e-04 3.90377094e-04 1.94543163e-03
#  4.95572121e-04 4.60250288e-04 6.86565266e-04 3.52819385e-03
#  6.64879660e-03 3.06669881e-02 9.11565959e-02 1.60901273e-01
#  6.31525882e-02 6.09327495e-01 0.00000000e+00 5.29017590e-07
#  0.00000000e+00 2.32341252e-05]

# %%
plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index=x.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# # Importing Necessary Libraries

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print("max r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %%
lreg=LinearRegression()
i=maxr2_score(lreg,x,y)
# Out:
# max r2 score corresponding to 95 is 0.9825351987003103

# %%
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Linear Regression: -2.3395021562747657e+25
# standard deviation in r2 score for Linear Regression 4.6790043125495315e+25

# %% [markdown]
# # Finding Best Parameters by Using GridSearchCV

# %%
knr=KNeighborsRegressor()
parameters={'n_neighbors':range(1,10),'algorithm':['auto', 'ball_tree', 'kd_tree']}
gd=GridSearchCV(knr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1],'selection' : ['cyclic', 'random']}
gd=GridSearchCV(lsreg,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

dtr=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae'),'max_features' : ['auto', 'sqrt', 'log2']}
gd=GridSearchCV(dtr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

enr=ElasticNet()
parametors={"alpha":[0.001,0.01,0.1,1]}
gd=GridSearchCV(enr,parametors)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

rfr=RandomForestRegressor()
parameters={"n_estimators":[10,50,100,120,150],"max_features": ["auto", "sqrt", "log2"]}
gd=GridSearchCV(rfr,parameters,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

svr=SVR()
parameters={"kernel" : ( "Linear" ,"rbf" ) ,"C": [1,10]}
gd=GridSearchCV(svr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,120,150]}
gd=GridSearchCV(gbr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")
# Out:
# {'algorithm': 'auto', 'n_neighbors': 3}
#
#
# {'alpha': 0.001, 'selection': 'cyclic'}
#
#
# {'criterion': 'mae', 'max_features': 'auto'}
#
#
# {'alpha': 0.001}
#
#
# {'max_features': 'auto', 'n_estimators': 10}
#
#
# {'C': 10, 'kernel': 'rbf'}
#
#
# {'learning_rate': 0.1, 'n_estimators': 150}

# %%
knn=KNeighborsRegressor(algorithm='auto', n_neighbors=3)
i=maxr2_score(knn,x,y)
print("\n")

print("Mean r2 score for KNeighbor  Regression:",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNeighbor   Regression",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
print("\n___________________________________________________________________________________________________________\n")

lsreg=Lasso(alpha=0.001, selection='cyclic')
i=maxr2_score(lsreg,x,y)
print("\n")

print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
print("\n___________________________________________________________________________________________________________\n")


dtr=DecisionTreeRegressor(criterion = 'mae',max_features='auto')
i=maxr2_score(dtr,x,y)
print("\n")

print("Mean r2 score for DecisionTreeRegressor :",cross_val_score(dtr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for DecisionTreeRegressor",cross_val_score(dtr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")

enr=ElasticNet(alpha=0.001)
i=maxr2_score(enr,x,y)
print("\n")

print("Mean r2 score for Elastic net Regression:",cross_val_score(enr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Elastic net Regression",cross_val_score(enr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")



rfr=RandomForestRegressor(max_features='auto',n_estimators=10)
i=maxr2_score(rfr,x,y)
print("\n")

print("Mean r2 score for RandomForestRegressor :",cross_val_score(rfr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for RandomForestRegressor ",cross_val_score(rfr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=150)
i=maxr2_score(gbr,x,y)
print("\n")

print("Mean r2 score for gradient boosting Regression:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for gradient boosting Regression",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


svr=SVR(C= 10, kernel= 'rbf')
i=maxr2_score(svr,x,y)
print("\n")

print("Mean r2 score for SVR:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for SVR",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")
# Out:
# max r2 score corresponding to 89 is 0.8711364720816955
#
#
# Mean r2 score for KNeighbor  Regression: 0.7117004435670018
# standard deviation in r2 score for KNeighbor   Regression 0.11329325626603882
#
# ___________________________________________________________________________________________________________
#
# max r2 score corresponding to 95 is 0.982021624031497
#
#
# Mean r2 score for Lasso Regression: 0.976502473527631
# standard deviation in r2 score for Lasso Regression 0.017889417083774048
#
# ___________________________________________________________________________________________________________
#
# max r2 score corresponding to 51 is 0.999710259312165
#
#
# Mean r2 score for DecisionTreeRegressor : 0.9879217716898309
# standard deviation in r2 score for DecisionTreeRegressor 0.019049182183836548
#
# _____________________________________________________________________________________________________________
#
# max r2 score corresponding to 95 is 0.9821076461951151
#
# ...

# %% [markdown]
# # From below DataFrame we can see that Decision Tree Regressor is the best Performing Model

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = 51,test_size=0.20)
dtr.fit(x_train,y_train)
y_pred=dtr.predict(x_test)

# %%
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# RMSE is:  0.01925957322802859
# r2_score is:  0.9990316341413212

# %% [markdown]
# # Saving Model

# %%
import joblib
model=joblib.dump(dtr,"ElectionData-pred.pkl")
