# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Auto_Insurance_Claims.csv')
df
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0     BU79786      US         KS    Kansas    276.351928       No     Basic
# 1     QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2     AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3     WW63253      US         MO  Missouri    764.586183       No     Basic
# 4     HB64268      US         KS    Kansas    281.369258       No     Basic
# ...       ...     ...        ...       ...           ...      ...       ...
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
# ...

# %%
#checking the datatype of each column 
print(df.dtypes)

print(df.info())
# Out:
# Customer                          object
# Country                           object
# State Code                        object
# State                             object
# Claim Amount                     float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Claim Reason                      object
# Sales Channel                     object
# ...

# %%
df.keys()
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
#checking the shape of data set
df.shape
# Out:
# (9134, 26)

# %%
#checking null values using heat map
sns.heatmap(df.isnull())
#we can see that their is no null values present

# %%
df.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %% [markdown]
# # Graphical Analysis

# %%
sns.countplot(df['State'])

# %%
sns.countplot(df['Response'])

# %%
sns.countplot(df['Marital Status'])

# %%
sns.countplot(df['Location Code'])

# %%
sns.countplot(df['Gender'])

# %%
sns.countplot(df['Coverage'])

# %%
sns.countplot(df['EmploymentStatus'])

# %%
plt.subplots(figsize=(10,10))
sns.countplot(df['Education'])

# %%
plt.subplots(figsize=(10,10))
sns.countplot(df['EmploymentStatus'])

# %%
sns.countplot(df['Policy Type'])

# %%
plt.subplots(figsize=(10,10))
sns.countplot(df['Policy'])

# %%
sns.countplot(df['Claim Reason'])

# %%
plt.subplots(figsize=(10,10))
sns.countplot(df['Vehicle Class'])

# %%
sns.countplot(df['Vehicle Size'])

# %%
plt.subplots(figsize=(20,20))
sns.countplot(x="Vehicle Class",hue="Vehicle Size",data=df)

# %%
plt.subplots(figsize=(20,20))
sns.countplot(x="EmploymentStatus",hue="Gender",data=df)

# %%
sns.catplot(y = "Total Claim Amount", x = "Claim Reason", data = df.sort_values("Total Claim Amount", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Claim Amount", x = "Vehicle Class", data = df.sort_values("Total Claim Amount", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Claim Amount", x = "Coverage", data = df.sort_values("Total Claim Amount", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Claim Amount", x = "Policy", data = df.sort_values("Total Claim Amount", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Claim Amount", x = "Vehicle Size", data = df.sort_values("Total Claim Amount", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
plt.violinplot(df["Months Since Policy Inception"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1d6efbe1640>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d6efbe14c0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d6efbe1520>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d6efbe1a90>}

# %%
plt.violinplot(df["Total Claim Amount"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1d6ef574880>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d6ef59faf0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d6efbaf970>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d6efc4c0a0>}

# %%
plt.violinplot(df["Monthly Premium Auto"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1d6ed162cd0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d6ed162430>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d6ee362d00>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d6ee3723a0>}

# %%
plt.violinplot(df["Months Since Last Claim"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1d6efda2a00>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d6efda2520>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d6efda24f0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d6ef596070>}

# %%
plt.violinplot(df["Income"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1d6ee9ecac0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d6ee9ec4f0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d6ee9ecfd0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d6ee9ecaf0>}

# %%
plt.violinplot(df["Claim Amount"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1d6ee810d30>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d6ee9efac0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d6ee8103a0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d6ee8105b0>}

# %%
plt.violinplot(df["Number of Policies"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1d6eea987f0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d6eea98640>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d6eea98670>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d6eea98c40>}

# %%
df.plot(kind='box',subplots=True,layout=(4,7),figsize=(20,20))
# Out:
# Claim Amount                        AxesSubplot(0.125,0.71587;0.0945122x0.16413)
# Income                           AxesSubplot(0.238415,0.71587;0.0945122x0.16413)
# Monthly Premium Auto             AxesSubplot(0.351829,0.71587;0.0945122x0.16413)
# Months Since Last Claim          AxesSubplot(0.465244,0.71587;0.0945122x0.16413)
# Months Since Policy Inception    AxesSubplot(0.578659,0.71587;0.0945122x0.16413)
# Number of Open Complaints        AxesSubplot(0.692073,0.71587;0.0945122x0.16413)
# Number of Policies               AxesSubplot(0.805488,0.71587;0.0945122x0.16413)
# Total Claim Amount                 AxesSubplot(0.125,0.518913;0.0945122x0.16413)
# dtype: object

# %%
# checking wheather data is normally distributed or not
for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D6F135AAF0>,
# ...
#       dtype=object)

# %%
sns.pairplot(df)

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#        Claim Amount        Income  Monthly Premium Auto  \
# count   9134.000000   9134.000000           9134.000000
# mean     800.494047  37657.380009             93.219291
# std      687.096761  30379.904734             34.407967
# min      189.800768      0.000000             61.000000
# 25%      399.425179      0.000000             68.000000
# 50%      578.018220  33889.500000             83.000000
# 75%      896.216704  62320.000000            109.000000
# max     8332.538119  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# ...

# %% [markdown]
# -> From the above analysis we can see that their is  diff between 75% and max in claim amount and total claim amount
#
# -> And mean is also greater than median in claim amount and total claim amout.So many outlier are their and data in both the columns will be skewed

# %%
#Observing corelation between the columns through heatmap
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# -> From the above analysis we can say that Total claim amount is negatively co-related with income, Number of open complaints and no of policies.
#
# ->And positively co-related with claim amount, monthly auto, months since last claim and months since policy Inception

# %%
df.corr()
# Out:
#                                Claim Amount    Income  Monthly Premium Auto  \
# Claim Amount                       1.000000  0.024366              0.396262
# Income                             0.024366  1.000000             -0.016665
# Monthly Premium Auto               0.396262 -0.016665              1.000000
# Months Since Last Claim            0.011517 -0.026715              0.005026
# Months Since Policy Inception      0.009418 -0.000875              0.020257
# Number of Open Complaints         -0.036343  0.006408             -0.013122
# Number of Policies                 0.021955 -0.008656             -0.011233
# Total Claim Amount                 0.226451 -0.355254              0.632017
#
#                                Months Since Last Claim  \
# Claim Amount                                  0.011517
# Income                                       -0.026715
# Monthly Premium Auto                          0.005026
# Months Since Last Claim                       1.000000
# ...

# %% [markdown]
# # Dropping unnecessary columns

# %%
df.drop(columns=["Customer"],inplace=True)
df.drop(columns=["Country"],inplace=True)
df.drop(columns=["Effective To Date"],inplace=True)

# %%
# Converting Object classs Data into Numerical Form by using Label Encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['Location Code','State Code','State','Gender','Marital Status','Education','Response','Coverage','EmploymentStatus','Policy Type','Policy','Claim Reason','Sales Channel','Vehicle Class','Vehicle Size']
for i in list1:
    df[i]=le.fit_transform(df[i].astype(str))

# %% [markdown]
# # Removing Outliers

# %%
print("The shape before removing outliers and skewness",df.shape)
print("skewness before removing outliers")
print(df.skew())
from scipy.stats import zscore
z=np.abs(zscore(df))
df=df[(z<3).all(axis=1)]
print("new shape after removing outliers",df.shape)
print("skewness after removing outliers")
print(df.skew())
# Out:
# The shape before removing outliers and skewness (9134, 23)
# skewness before removing outliers
# State Code                       0.021065
# State                            0.021065
# Claim Amount                     3.032280
# Response                         2.037567
# Coverage                         1.031310
# Education                        0.333148
# EmploymentStatus                 0.832147
# Gender                           0.039866
# Income                           0.286887
# Location Code                    0.009511
# Marital Status                  -0.107553
# Monthly Premium Auto             2.123546
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        2.783263
# Number of Policies               1.253333
# Policy Type                     -0.468383
# Policy                          -0.427639
# Claim Reason                     0.733526
# Sales Channel                    0.506774
# ...

# %% [markdown]
# # Splitting the data into input and target

# %%
x=df.drop('Total Claim Amount',axis=1)
y=df['Total Claim Amount']

# %%
x.head()
# Out:
#    State Code  State  Claim Amount  Response  Coverage  Education  \
# 0           1      1    276.351928         0         0          0
# 1           3      3    697.953590         0         1          0
# 2           4      4   1288.743165         0         2          0
# 3           2      2    764.586183         0         0          0
# 4           1      1    281.369258         0         0          0
#
#    EmploymentStatus  Gender  Income  Location Code  ...  \
# 0                 1       0   56274              1  ...
# 1                 4       0       0              1  ...
# 2                 1       0   48767              1  ...
# 3                 4       1       0              1  ...
# 4                 1       1   43836              0  ...
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
# 1                       13                             42
# ...

# %%
y.head()
# Out:
# 0     384.811147
# 1    1131.464935
# 2     566.472247
# 3     529.881344
# 4     138.130879
# Name: Total Claim Amount, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (8470, 22)
# (8470,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (8470, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=scaler.fit_transform(x)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print("max r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %%
lreg=LinearRegression()
i=maxr2_score(lreg,x,y)
# Out:
# max r2 score corresponding to 96 is 0.5598435225634594

# %%
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Linear Regression: 0.5243320647181704
# standard deviation in r2 score for Linear Regression 0.011261114372893203

# %% [markdown]
# # Finding Best Parameters by Using GridSearchCV

# %%
knr=KNeighborsRegressor()
parameters={'n_neighbors':range(1,10)}
gd=GridSearchCV(knr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
gd=GridSearchCV(lsreg,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

dtr=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae')}
gd=GridSearchCV(dtr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

enr=ElasticNet()
parametors={"alpha":[0.001,0.01,0.1,1]}
gd=GridSearchCV(enr,parametors)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

rfr=RandomForestRegressor()
parameters={"n_estimators":[10,50,100,120,150],"max_features": ["auto", "sqrt", "log2"]}
gd=GridSearchCV(rfr,parameters,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

svr=SVR()
parameters={"kernel" : ( "Linear" ,"rbf" ) ,"C": [1,10]}
gd=GridSearchCV(svr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,120,150]}
gd=GridSearchCV(gbr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")
# Out:
# {'n_neighbors': 7}
#
#
# {'alpha': 1}
#
#
# {'criterion': 'mse'}
#
#
# {'alpha': 0.01}
#
#
# {'max_features': 'auto', 'n_estimators': 150}
#
#
# {'C': 10, 'kernel': 'rbf'}
#
#
# {'learning_rate': 0.1, 'n_estimators': 150}

# %%
knn=KNeighborsRegressor(n_neighbors=7)
i=maxr2_score(knn,x,y)
print("\n")

print("Mean r2 score for KNeighbor  Regression:",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNeighbor   Regression",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
print("\n___________________________________________________________________________________________________________\n")

lsreg=Lasso(alpha=1)
i=maxr2_score(lsreg,x,y)
print("\n")

print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
print("\n___________________________________________________________________________________________________________\n")


dtr=DecisionTreeRegressor(criterion = 'mse')
i=maxr2_score(dtr,x,y)
print("\n")

print("Mean r2 score for DecisionTreeRegressor :",cross_val_score(dtr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for DecisionTreeRegressor",cross_val_score(dtr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")

enr=ElasticNet(alpha=0.01)
i=maxr2_score(enr,x,y)
print("\n")

print("Mean r2 score for Elastic net Regression:",cross_val_score(enr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Elastic net Regression",cross_val_score(enr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


rfr=RandomForestRegressor(max_features='auto',n_estimators=150)
i=maxr2_score(rfr,x,y)
print("\n")

print("Mean r2 score for RandomForestRegressor :",cross_val_score(rfr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for RandomForestRegressor ",cross_val_score(rfr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=150)
i=maxr2_score(gbr,x,y)
print("\n")

print("Mean r2 score for gradient boosting Regression:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for gradient boosting Regression",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


svr=SVR(C= 10, kernel= 'rbf')
i=maxr2_score(svr,x,y)
print("\n")

print("Mean r2 score for SVR:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for SVR",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")
# Out:
# max r2 score corresponding to 79 is 0.669752112252256
#
#
# Mean r2 score for KNeighbor  Regression: 0.6273331988072083
# standard deviation in r2 score for KNeighbor   Regression 0.00861456073032962
#
# ___________________________________________________________________________________________________________
#
# max r2 score corresponding to 96 is 0.559559254190215
#
#
# Mean r2 score for Lasso Regression: 0.5244947348260236
# standard deviation in r2 score for Lasso Regression 0.011419944011920072
#
# ___________________________________________________________________________________________________________
#
# max r2 score corresponding to 66 is 0.7073036814901187
#
#
# Mean r2 score for DecisionTreeRegressor : 0.6652575869290186
# standard deviation in r2 score for DecisionTreeRegressor 0.02561462829021264
#
# _____________________________________________________________________________________________________________
#
# max r2 score corresponding to 96 is 0.5596448314634044
#
# ...

# %% [markdown]
# # From the above analysis w.r.t r2_score GradientBoost Regressor is performing best

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = 79,test_size=0.20)
gbr.fit(x_train,y_train)
y_pred=gbr.predict(x_test)

# %%
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print('MAE:', mean_absolute_error(y_test,y_pred))
print('MSE:', mean_squared_error(y_test,y_pred))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# RMSE is:  94.15919169312163
# MAE: 69.37321916200042
# MSE: 8865.953380302024
# r2_score is:  0.8413010779105802

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(gbr,"Insurance_Claims-Data.pkl")
# Out:
# ['Insurance_Claims-Data.pkl']
