# %%
#Importing Libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the data set
df=pd.read_csv('Space-Server.csv')
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
#checking the datatype of each column 
print(df.dtypes)
# All features are of float type except run,rerun,camcol,field,plate,mjd,fiberid which is integer type
# Class(The predicted Value) is a object type data
print(df.info())
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
# ...

# %%
df.keys()
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %% [markdown]
# # Attribute Information
#
# objid = Object Identifier
#
# ra = J2000 Right Ascension (r-band)
#
# dec = J2000 Declination (r-band)
#
# u = better of DeV/Exp magnitude fit
#
# g = better of DeV/Exp magnitude fit
#
# r = better of DeV/Exp magnitude fit
#
# i = better of DeV/Exp magnitude fit
#
# z = better of DeV/Exp magnitude fit
#
# run = Run Number
#
# rereun = Rerun Number
#
# camcol = Camera column
#
# field = Field number
#
# specobjid = Object Identifier
#
# redshift = Final Redshift
#
# plate = plate number
#
# mjd = MJD of observation
#
# fiberid = fiber ID
#
# class(Predicted Value) = object class (galaxy, star or quasar object)

# %%
#checking the shape of data set
df.shape
# Out:
# (10000, 18)

# %%
#checking null values using heat map
sns.heatmap(df.isnull())
#we can see that their is no null values present

# %%
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.countplot(df['class'])

# %%
sns.countplot(df['rerun'])

# %%
plt.subplots(figsize=(15,15))
sns.countplot(df['run'])

# %%
sns.countplot(df['camcol'])

# %%
plt.figure(figsize=(8,5))
sns.barplot(x = "run" ,y="class" ,data=df )

# %%
sns.distplot(df['dec'])

# %%
sns.distplot(df['redshift'])

# %%
sns.distplot(df['plate'])

# %%
sns.distplot(df['mjd'])

# %%
sns.distplot(df['class'])

# %%
plt.subplots(nrows=1, ncols=1,figsize=(16, 4))
ax = sns.lvplot(x=df['class'], y=df['dec'], palette='coolwarm')
ax.set_title('dec')
# Out:
# Text(0.5, 1.0, 'dec')

# %% [markdown]
# ->Star : The largest part of the value lie within 0 to 10 range.Another large part lie between about 10 to 55. Only small amounts of data are lower or higher than these ranges.
#
# ->Galaxy: The largest part of values lies between 0 and 45. There is a smaller amount of values in the range of 45 to 60.
#
# ->QSO: This plot looks quite similiar to the GALAXY plot. Only the amount of data points in the range of 0 to 60 is bigger.

# %%
# from below observation we can say that many outliers are present in ApplicantIncome, CoaaplicantIncome, LoanAmount

df.plot(kind='box',subplots=True,layout=(3,7),figsize=(20,20))
# Out:
# objid           AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# ra           AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# dec          AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# u            AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# g            AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# r            AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# i            AxesSubplot(0.805488,0.657941;0.0945122x0.222059)
# z               AxesSubplot(0.125,0.391471;0.0945122x0.222059)
# run          AxesSubplot(0.238415,0.391471;0.0945122x0.222059)
# rerun        AxesSubplot(0.351829,0.391471;0.0945122x0.222059)
# camcol       AxesSubplot(0.465244,0.391471;0.0945122x0.222059)
# field        AxesSubplot(0.578659,0.391471;0.0945122x0.222059)
# specobjid    AxesSubplot(0.692073,0.391471;0.0945122x0.222059)
# redshift     AxesSubplot(0.805488,0.391471;0.0945122x0.222059)
# plate              AxesSubplot(0.125,0.125;0.0945122x0.222059)
# ...

# %%
plt.hist(df["camcol"],bins=10)
plt.title("camcol")
# Out:
# Text(0.5, 1.0, 'camcol')

# %%
plt.hist(df["dec"],bins=20)
plt.title("dec")
# Out:
# Text(0.5, 1.0, 'dec')

# %%
plt.hist(df["fiberid"],bins=100)
plt.title("fiberid")
# Out:
# Text(0.5, 1.0, 'fiberid')

# %%
plt.hist(df["field"],bins=100)
plt.title("field")
# Out:
# Text(0.5, 1.0, 'field')

# %%
plt.hist(df["g"],bins=10)
plt.title("g")
# Out:
# Text(0.5, 1.0, 'g')

# %%
plt.hist(df["i"],bins=10)
plt.title("i")
# Out:
# Text(0.5, 1.0, 'i')

# %%
sns.pairplot(df)

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %%
#Observing corelation between the columns through heatmap
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.corr()
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# rerun               NaN           NaN           NaN           NaN
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# ...

# %% [markdown]
# -> From the above analysis we can see that u,g,r,i,z are highly co-related
# so we can reduce the amount of dimensions by replacing u, g , r , i , z with only 3 dimentions using Principal Component Analysis

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
df1 = pca.fit_transform(df[['u', 'g', 'r', 'i', 'z']])

# %%
df = pd.concat((df, pd.DataFrame(df1)), axis=1)
df.rename({0: 'PCA_1', 1: 'PCA_2', 2: 'PCA_3'}, axis=1, inplace = True)
df.drop(['u', 'g', 'r', 'i', 'z'], axis=1, inplace=True)
df.head()
# Out:
#           objid          ra       dec  run  rerun  camcol  field  \
# 0  1.237650e+18  183.531326  0.089693  752    301       4    267
# 1  1.237650e+18  183.598371  0.135285  752    301       4    267
# 2  1.237650e+18  183.680207  0.126185  752    301       4    268
# 3  1.237650e+18  183.870529  0.049911  752    301       4    269
# 4  1.237650e+18  183.883288  0.102557  752    301       4    269
#
#       specobjid   class  redshift  plate    mjd  fiberid     PCA_1     PCA_2  \
# 0  3.722360e+18    STAR -0.000009   3306  54922      491 -1.507202 -1.377293
# 1  3.638140e+17    STAR -0.000055    323  51615      541 -0.195758 -0.028410
# 2  3.232740e+17  GALAXY  0.123111    287  52023      513  1.297604 -0.590023
# 3  3.722370e+18    STAR -0.000111   3306  54922      510 -1.446117  0.566685
# 4  3.722370e+18    STAR  0.000590   3306  54922      512 -0.849271  1.287505
#
#       PCA_3
# 0 -0.265119
# 1 -0.155695
# 2  0.140338
# 3 -0.009272
# 4 -0.397689

# %% [markdown]
# # Dropping unnecessary columns

# %%
df.drop(columns=["objid"],inplace=True)
df.drop(columns=["rerun"],inplace=True)
df.drop(columns=["specobjid"],inplace=True)
df.drop(columns=["fiberid"],inplace=True)
df.drop(columns=["camcol"],inplace=True)
df.drop(columns=["run"],inplace=True)

# %%
df.head()
# Out:
#            ra       dec  field   class  redshift  plate    mjd     PCA_1  \
# 0  183.531326  0.089693    267    STAR -0.000009   3306  54922 -1.507202
# 1  183.598371  0.135285    267    STAR -0.000055    323  51615 -0.195758
# 2  183.680207  0.126185    268  GALAXY  0.123111    287  52023  1.297604
# 3  183.870529  0.049911    269    STAR -0.000111   3306  54922 -1.446117
# 4  183.883288  0.102557    269    STAR  0.000590   3306  54922 -0.849271
#
#       PCA_2     PCA_3
# 0 -1.377293 -0.265119
# 1 -0.028410 -0.155695
# 2 -0.590023  0.140338
# 3  0.566685 -0.009272
# 4  1.287505 -0.397689

# %%
# Converting Object classs Data into Numerical Form by using Label Encoder
rom sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['class']
for i in list1:
    train[i]=le.fit_transform(train[i].astype(str))

# %% [markdown]
# # Removing Outliers

# %%
print("The shape before removing outliers and skewness",df.shape)
print("skewness before removing outliers")
print(df.skew())
from scipy.stats import zscore
z=np.abs(zscore(df))
df=df[(z<3).all(axis=1)]
print("new shape after removing outliers",df.shape)
print("skewness after removing outliers")
print(df.skew())
# Out:
# The shape before removing outliers and skewness (10000, 10)
# skewness before removing outliers
# ra         -1.227350
# dec         1.191544
# field       0.249795
# class       0.169292
# redshift    4.265729
# plate       1.794609
# mjd         1.039610
# PCA_1      -0.157247
# PCA_2       0.645904
# PCA_3       0.451664
# dtype: float64
# new shape after removing outliers (8671, 10)
# skewness after removing outliers
# ra         -0.133747
# dec         1.221951
# field       0.216009
# class       0.293784
# redshift    4.967485
# plate       1.287202
# mjd         0.942471
# PCA_1      -0.179095
# PCA_2       0.374453
# PCA_3      -0.228697
# dtype: float64

# %% [markdown]
# # Splitting the data into input and target

# %%
x=df.drop('class',axis=1)
y=df['class']

# %%
x.head()
# Out:
#            ra       dec  field  redshift  plate    mjd     PCA_1     PCA_2  \
# 0  183.531326  0.089693    267 -0.000009   3306  54922 -1.507202 -1.377293
# 1  183.598371  0.135285    267 -0.000055    323  51615 -0.195758 -0.028410
# 2  183.680207  0.126185    268  0.123111    287  52023  1.297604 -0.590023
# 3  183.870529  0.049911    269 -0.000111   3306  54922 -1.446117  0.566685
# 4  183.883288  0.102557    269  0.000590   3306  54922 -0.849271  1.287505
#
#       PCA_3
# 0 -0.265119
# 1 -0.155695
# 2  0.140338
# 3 -0.009272
# 4 -0.397689

# %%
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    2
# Name: class, dtype: int32

# %%
print(x.shape)
print(y.shape)
# Out:
# (8671, 9)
# (8671,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (8671, 1)

# %%
#Scaling all values to be within the (0, 1) interval By using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x=scaler.fit_transform(x)

# %% [markdown]
# # Importing Necessary Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,f1_score, classification_report, roc_auc_score, roc_curve,auc

# %%
def max_acc_score(clf,x,y):
    max_acc_score=0
    for i in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        clf.fit(x_train,y_train)
        pred=clf.predict(x_test)
        acc_score=accuracy_score(pred,y_test)
        
        if acc_score>max_acc_score:
            max_acc_score=acc_score
            final_i=i
    print("max acc score corresponding to",final_i,"is",max_acc_score)
    return final_i

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (6936, 9)
# (6936, 1)
# (1735, 9)
# (1735, 1)

# %% [markdown]
# # Finding Best Parameters by Using GridSearchCV

# %%
#Best parameters for SVC
from sklearn.svm import SVC
sv=SVC()
parameters={"kernel" : ( "Linear" ,"rbf" ) ,"C": [1,10]}
gd=GridSearchCV(sv,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")

#Best parameters for KNeighborsClassifier
knn=KNeighborsClassifier()
parameters={"n_neighbors" :range(1,20)}
gd=GridSearchCV(knn,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")


#Best parameters for DecisionTreeClassifier
dtc=DecisionTreeClassifier()
parameters={"criterion" :("gini" ,"entropy")}
gd=GridSearchCV(dtc,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")

#Best parameters for  RandomForestClassifier
rfc=RandomForestClassifier()
parameters={"n_estimators":[10,50,100,120,150],"max_features": ["auto", "sqrt", "log2"]}
gd=GridSearchCV(rfc,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")


#Best parameters for  AdaboostClassifier 
ada=AdaBoostClassifier()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,120,150,200]}
gd=GridSearchCV(ada,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")


#Best parameters for  GradientBoostingClassifier
gbc=GradientBoostingClassifier()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,120,150]}
gd=GridSearchCV(gbc,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")
# Out:
# {'C': 10, 'kernel': 'rbf'}
#
#
# {'n_neighbors': 3}
#
#
# {'criterion': 'gini'}
#
#
# {'max_features': 'auto', 'n_estimators': 120}
#
#
# {'learning_rate': 1, 'n_estimators': 10}
#
#
# {'learning_rate': 0.1, 'n_estimators': 50}

# %%
model=[]
score=[]
cvs=[]
rocscore=[]

for i in [KNeighborsClassifier(n_neighbors=3),SVC(C=10,kernel='rbf'),MultinomialNB(),
          DecisionTreeClassifier(criterion='gini'),GradientBoostingClassifier(learning_rate=0.01,n_estimators=50),
          RandomForestClassifier(max_features='auto',n_estimators=120),AdaBoostClassifier(learning_rate=1,n_estimators=10)]:
    k=i
    model.append(i)
    print("\n")
    print("The model score for",i,"are:")
    k.fit(x_train,y_train)
    k.score(x_train,y_train)
    predict=k.predict(x_test)
    print(predict)
    AS=accuracy_score(predict,y_test)
    print("Accuracy score =", AS)
    score.append(AS)
    cv_score=cross_val_score(k,x,y,cv=5,scoring="accuracy").mean()
    print("The cv score is",cv_score)
    cvs.append(cv_score)
    print("")
    cm=confusion_matrix(predict,y_test)
    print(cm)
    print("")
    print(classification_report(predict,y_test))
    print("\n")
# Out:
# The model score for KNeighborsClassifier(n_neighbors=3) are:
# [0 0 0 ... 0 1 2]
# Accuracy score = 0.9613832853025936
# The cv score is 0.9575598389889943
#
# [[921   9  26]
#  [  2  84   1]
#  [ 28   1 663]]
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97       956
#            1       0.89      0.97      0.93        87
#            2       0.96      0.96      0.96       692
#
#     accuracy                           0.96      1735
#    macro avg       0.94      0.96      0.95      1735
# weighted avg       0.96      0.96      0.96      1735
#
#
#
#
#
# The model score for SVC(C=10) are:
# [0 0 0 ... 0 1 2]
# Accuracy score = 0.985014409221902
# The cv score is 0.9840847069460095
#
# [[935   6   2]
#  [  2  87   1]
#  [ 14   1 687]]
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       943
#            1       0.93      0.97      0.95        90
# ...

# %%
result=pd.DataFrame({'Model':['KNeighborsClassifier','SVC','MultinomialNB','DecisionTreeClassifier','GradientBoostingClassifier','RandomForestClassifier','AdaBoostClassifier'],'Accuracy_Score':score,'Cross_val_score':cvs})
result
# Out:
#                         Model  Accuracy_Score  Cross_val_score
# 0        KNeighborsClassifier        0.961383         0.957560
# 1                         SVC        0.985014         0.984085
# 2               MultinomialNB        0.818444         0.831620
# 3      DecisionTreeClassifier        0.990202         0.990312
# 4  GradientBoostingClassifier        0.984438         0.988467
# 5      RandomForestClassifier        0.992507         0.991927
# 6          AdaBoostClassifier        0.983285         0.760345

# %% [markdown]
# # From the above analysis w.r.t r2_score RandomForestClassifier is performing best

# %%
rfc=RandomForestClassifier(max_features='auto',n_estimators=120)
rfc.fit(x_train,y_train)
predict=rfc.predict(x_test)
AS=accuracy_score(predict,y_test)
print("Accuracy Score =",AS)
cv_score=cross_val_score(k,x,y,cv=5,scoring="accuracy").mean()
print("The CV Score =",cv_score)
# Out:
# Accuracy Score = 0.992507204610951
# The CV Score = 0.7603452894973891

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(rfc,"Space_Server.pkl")
# Out:
# ['Space_Server.pkl']
