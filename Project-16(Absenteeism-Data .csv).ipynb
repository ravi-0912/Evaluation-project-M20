# %%
#Importing Libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('Absenteeism_at_work.xls')
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
#checking the datatype of each column 
print(df.dtypes)
# All features are of integer type
print(df.info())
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# ...

# %%
df.shape
# Out:
# (740, 21)

# %%
#checking null values using heat map
sns.heatmap(df.isnull())
#we can see that their is no null values

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
df["Reason for absence"].value_counts()
# Out:
# 23    149
# 28    112
# 27     69
# 13     55
# 0      43
# 19     40
# 22     38
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 6       8
# 12      8
# 8       6
# 21      6
# 9       4
# 5       3
# 24      3
# 16      3
# 4       2
# 15      2
# 3       1
# 2       1
# 17      1
# Name: Reason for absence, dtype: int64

# %%
df["Hit target"].value_counts()
# Out:
# 93     105
# 99     102
# 97      89
# 92      79
# 96      75
# 95      75
# 98      66
# 91      45
# 94      34
# 88      28
# 81      19
# 87      12
# 100     11
# Name: Hit target, dtype: int64

# %% [markdown]
# # Reason for absence (ICD)
#
# 0-> Certain infectious and parasitic diseases
#
# 1> Neoplasms
#
# 2> Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism
#
# 3> Endocrine, nutritional and metabolic diseases
#
# 4> Mental and behavioural disorders
#
# 5> Diseases of the nervous system
#
# 6> Diseases of the eye and adnexa
#
# 7> Diseases of the ear and mastoid process
#
# 8> Diseases of the circulatory system
#
# 9> Diseases of the respiratory system
#
# 10> Diseases of the digestive system
#
# 11> Diseases of the skin and subcutaneous tissue
#
# 12>Diseases of the musculoskeletal system and connective tissue
#
# 13> Diseases of the genitourinary system
#
# 14> Pregnancy, childbirth and the puerperium
#
# 15> Certain conditions originating in the perinatal period
#
# 16>Congenital malformations, deformations and chromosomal abnormalities
#
# 17> Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified
#
# 18> Injury, poisoning and certain other consequences of external causes
#
# 19> External causes of morbidity and mortality
#
# 20> Factors influencing health status and contact with health services.
#
# 21> Patient follow-up
#
# 22> Medical consultation
#
# 23>blood donation
#
# 24>laboratory examination
#
# 25>unjustified absense
#
# 26>physiotherapy
#
# 27>dental consultation

# %% [markdown]
# # Data Analysis Through Visualization

# %%
plt.subplots(figsize=(15,15))
sns.countplot(df["Reason for absence"])

# %%
sns.countplot(df["Month of absence"])

# %%
sns.countplot(df["Day of the week"])

# %% [markdown]
# Monday (2), Tuesday (3), Wednesday (4), Thursday (5), Friday (6)

# %%
sns.countplot(df["Seasons"])

# %% [markdown]
# summer (1), autumn (2), winter (3), spring (4)

# %%
sns.countplot(df["Education"])

# %% [markdown]
# high school (1), graduate (2), postgraduate (3), master and doctor (4)

# %%
plt.violinplot(df["Transportation expense"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2a934d35a00>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2a934cc7460>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2a934d35e80>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2a934d44190>}

# %%
plt.violinplot(df["Height"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2a934d88eb0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2a934d88d00>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2a934d95340>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2a934d95610>}

# %%
plt.violinplot(df["Distance from Residence to Work"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2a934de27c0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2a934de2520>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2a934de2670>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2a934de2c10>}

# %%
sns.boxplot(x='Month of absence',y='Absenteeism time in hours',data=df)

# %%
sns.boxplot(x='Day of the week',y='Absenteeism time in hours',data=df)

# %%
plt.subplots(figsize=(10,10))
sns.boxplot(x='Reason for absence',y='Absenteeism time in hours',data=df)

# %%
sns.boxplot(x='Seasons',y='Absenteeism time in hours',data=df)

# %%
sns.catplot(y = "Absenteeism time in hours", x = "Education", data = df.sort_values("Absenteeism time in hours", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Absenteeism time in hours", x = "Social drinker", data = df.sort_values("Absenteeism time in hours", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %% [markdown]
#                             Social drinker (yes=1; no=0)

# %%
for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %%
# from below observation we can say that many outliers are present in Age,Fnlwgt,capital gain, capital loss and hours per week

df.plot(kind='box',subplots=True,layout=(3,7),figsize=(20,20))
# Out:
# ID                                    AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# Reason for absence                 AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# Month of absence                   AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# Day of the week                    AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# Seasons                            AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# Transportation expense             AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# Distance from Residence to Work    AxesSubplot(0.805488,0.657941;0.0945122x0.222059)
# Service time                          AxesSubplot(0.125,0.391471;0.0945122x0.222059)
# Age                                AxesSubplot(0.238415,0.391471;0.0945122x0.222059)
# Work load Average/day              AxesSubplot(0.351829,0.391471;0.0945122x0.222059)
# Hit target                         AxesSubplot(0.465244,0.391471;0.0945122x0.222059)
# ...

# %%
plt.hist(df['Age'],bins = 20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age")
plt.show()

# %%
plt.hist(df['Service time'],bins = 20)
plt.xlabel("Service time")
plt.ylabel("Frequency")
plt.title("Histogram of Service time")
# Out:
# Text(0.5, 1.0, 'Histogram of Service time')

# %%
plt.hist(df['Work load Average/day '],bins = 20)
plt.xlabel("Work load Average/day")
plt.ylabel("Frequency")
plt.title("Histogram of Work load Average/day")
# Out:
# Text(0.5, 1.0, 'Histogram of Work load Average/day')

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
df.dtypes
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ->From above analysis we can say that Absenteeism time in houes is negatively co-related with reason for absense,Day of the week,season,distance from residance to home,disciplinary failure,education, social distance,pet and body mass index...Rest are positively co-related

# %% [markdown]
# # Removing Outliers

# %%
print("The shape before removing outliers",df.shape)
print("skewness before removing outliers")
print(df.skew())
from scipy.stats import zscore
z=np.abs(zscore(df))
df1=df[(z<3).all(axis=1)]
print("New shape after removing outliers",df1.shape)
print("skewness after removing outliers")
print(df1.skew())
# Out:
# The shape before removing outliers (740, 21)
# skewness before removing outliers
# ID                                 0.016606
# Reason for absence                -0.915312
# Month of absence                   0.069369
# Day of the week                    0.102440
# Seasons                           -0.038532
# Transportation expense             0.396189
# Distance from Residence to Work    0.312083
# Service time                      -0.004720
# Age                                0.697703
# Work load Average/day              0.961457
# Hit target                        -1.261708
# Disciplinary failure               3.952270
# Education                          2.108953
# Son                                1.086465
# Social drinker                    -0.273327
# Social smoker                      3.290333
# Pet                                2.735715
# Weight                             0.017001
# Height                             2.566060
# ...

# %%
for i in df1.columns:
    if df1.skew().loc[i]>0.55:
        df1[i]=np.log1p(df1[i])

# %% [markdown]
# # Splitting the data into input and target

# %%
x=df1.drop(['Absenteeism time in hours'],axis=1)
y=df1['Absenteeism time in hours']

# %%
x.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 2   3                  23                 7                4        1
# 4  11                  23                 7                5        1
# 5   3                  23                 7                6        1
# 6  10                  22                 7                6        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 2                     179                               51            18   38
# 4                     289                               36            13   33
# 5                     179                               51            18   38
# 6                     361                               52             3   28
#
#    Work load Average/day   Hit target  Disciplinary failure  Education  \
# ...

# %%
y.head()
# Out:
# 0    1.609438
# 2    1.098612
# 4    1.098612
# 5    1.098612
# 6    2.197225
# Name: Absenteeism time in hours, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (576, 20)
# (576,)

# %%
x.skew()
# Out:
# ID                                -0.058065
# Reason for absence                -1.027334
# Month of absence                   0.109690
# Day of the week                    0.082048
# Seasons                           -0.019301
# Transportation expense             0.327717
# Distance from Residence to Work    0.199294
# Service time                      -0.153111
# Age                                0.517042
# Work load Average/day              0.668491
# Hit target                        -0.461369
# Disciplinary failure               0.000000
# Education                          1.950332
# Son                                0.575525
# Social drinker                    -0.188822
# Social smoker                      0.000000
# Pet                                0.962203
# Weight                            -0.128296
# Height                             1.367054
# Body mass index                    0.037118
# dtype: float64

# %%
# scaling data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(scaler.fit(x))
# Out:
# StandardScaler()

# %%
x.skew()
# Out:
# ID                                -0.058065
# Reason for absence                -1.027334
# Month of absence                   0.109690
# Day of the week                    0.082048
# Seasons                           -0.019301
# Transportation expense             0.327717
# Distance from Residence to Work    0.199294
# Service time                      -0.153111
# Age                                0.517042
# Work load Average/day              0.668491
# Hit target                        -0.461369
# Disciplinary failure               0.000000
# Education                          1.950332
# Son                                0.575525
# Social drinker                    -0.188822
# Social smoker                      0.000000
# Pet                                0.962203
# Weight                            -0.128296
# Height                             1.367054
# Body mass index                    0.037118
# dtype: float64

# %% [markdown]
# # Importing Necessary Libraries

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print("max r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %%
lreg=LinearRegression()
i=maxr2_score(lreg,x,y)
# Out:
# max r2 score corresponding to 84 is 0.40465279773404206

# %%
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Linear Regression: 0.16542954656355563
# standard deviation in r2 score for Linear Regression 0.08589439876483988

# %% [markdown]
# # Finding Best Parameters by Using GridSearchCV

# %%
knr=KNeighborsRegressor()
parameters={'n_neighbors':range(1,10),'algorithm':['auto', 'ball_tree', 'kd_tree']}
gd=GridSearchCV(knr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1],'selection' : ['cyclic', 'random']}
gd=GridSearchCV(lsreg,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

dtr=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae'),'max_features' : ['auto', 'sqrt', 'log2']}
gd=GridSearchCV(dtr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

enr=ElasticNet()
parametors={"alpha":[0.001,0.01,0.1,1]}
gd=GridSearchCV(enr,parametors)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

rfr=RandomForestRegressor()
parameters={"n_estimators":[10,50,100,120,150],"max_features": ["auto", "sqrt", "log2"]}
gd=GridSearchCV(rfr,parameters,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

svr=SVR()
parameters={"kernel" : ( "Linear" ,"rbf" ) ,"C": [1,10]}
gd=GridSearchCV(svr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,120,150]}
gd=GridSearchCV(gbr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")
# Out:
# {'algorithm': 'ball_tree', 'n_neighbors': 9}
#
#
# {'alpha': 0.001, 'selection': 'random'}
#
#
# {'criterion': 'mae', 'max_features': 'auto'}
#
#
# {'alpha': 0.001}
#
#
# {'max_features': 'auto', 'n_estimators': 120}
#
#
# {'C': 10, 'kernel': 'rbf'}
#
#
# {'learning_rate': 0.1, 'n_estimators': 50}

# %%
knn=KNeighborsRegressor(algorithm='ball_tree', n_neighbors=9)
i=maxr2_score(knn,x,y)
print("\n")

print("Mean r2 score for KNeighbor  Regression:",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNeighbor   Regression",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
print("\n___________________________________________________________________________________________________________\n")

lsreg=Lasso(alpha=0.001, selection='random')
i=maxr2_score(lsreg,x,y)
print("\n")

print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
print("\n___________________________________________________________________________________________________________\n")


dtr=DecisionTreeRegressor(criterion = 'mae',max_features='auto')
i=maxr2_score(dtr,x,y)
print("\n")

print("Mean r2 score for DecisionTreeRegressor :",cross_val_score(dtr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for DecisionTreeRegressor",cross_val_score(dtr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")

enr=ElasticNet(alpha=0.001)
i=maxr2_score(enr,x,y)
print("\n")

print("Mean r2 score for Elastic net Regression:",cross_val_score(enr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Elastic net Regression",cross_val_score(enr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")



rfr=RandomForestRegressor(max_features='auto',n_estimators=120)
i=maxr2_score(rfr,x,y)
print("\n")

print("Mean r2 score for RandomForestRegressor :",cross_val_score(rfr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for RandomForestRegressor ",cross_val_score(rfr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=50)
i=maxr2_score(gbr,x,y)
print("\n")

print("Mean r2 score for gradient boosting Regression:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for gradient boosting Regression",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


svr=SVR(C= 10, kernel= 'rbf')
i=maxr2_score(svr,x,y)
print("\n")

print("Mean r2 score for SVR:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for SVR",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")
# Out:
# max r2 score corresponding to 84 is 0.44881184850679523
#
#
# Mean r2 score for KNeighbor  Regression: 0.12070216171160415
# standard deviation in r2 score for KNeighbor   Regression 0.1551438729388533
#
# ___________________________________________________________________________________________________________
#
# max r2 score corresponding to 84 is 0.39961726941017406
#
#
# Mean r2 score for Lasso Regression: 0.16903539400073017
# standard deviation in r2 score for Lasso Regression 0.0963146912201598
#
# ___________________________________________________________________________________________________________
#
# max r2 score corresponding to 62 is 0.29800281919470917
#
#
# Mean r2 score for DecisionTreeRegressor : -0.2443769319909311
# standard deviation in r2 score for DecisionTreeRegressor 0.26949765124784636
#
# _____________________________________________________________________________________________________________
#
# ...

# %%
ada=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[20,50,100,120,150,200]}
gd=GridSearchCV(ada,parameters)
gd.fit(x,y)
print(gd.best_params_)
# Out:
# {'learning_rate': 0.01, 'n_estimators': 20}

# %%
ada=AdaBoostRegressor(n_estimators= 20, learning_rate = 0.01)
i=maxr2_score(ada,x,y)
# Out:
# max r2 score corresponding to 87 is 0.4723983288119419

# %%
print("Mean r2 score for AdaBoostRegressor :",cross_val_score(ada,x,y,cv=10,scoring="r2").mean())
print("standard deviation in r2 score for AdaBoostRegressor ",cross_val_score(ada,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for AdaBoostRegressor : 0.28783668876221674
# standard deviation in r2 score for AdaBoostRegressor  0.10403493295799861

# %% [markdown]
# # From the above analysis w.r.t r2_score Random Forest Regressor is performing best

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=76,test_size=0.20)
rfr=RandomForestRegressor(max_features='auto',n_estimators=120)
rfr.fit(x,y)
y_pred=rfr.predict(x_test)

# %%
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is:",r2_score(y_test,y_pred))
# Out:
# RMSE is:  0.19520945526490144
# r2_score is: 0.9228783579363798

# %%
prediction = rfr.predict(x_test)

# %%
r2_score(y_test,prediction)
# Out:
# 0.9228783579363798

# %% [markdown]
# # Saving Model

# %%
import joblib
model=joblib.dump(rfr,"Absenteeism_at_work.pkl")
