# %%
#Importing Libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Covid-19_Dataset.csv')
df
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-18                 Russia   145927292    1831892.0      36793.0
# 2     2020-04-18                  Spain    46752703     930230.0     194416.0
# 3     2020-04-18                 Brazil   212380932      62985.0      36722.0
# 4     2020-04-18                     UK    67844241     460437.0     114217.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-18              St. Barth        9874          NaN          6.0
# 6599  2020-05-18         Western Sahara      595462          NaN          6.0
# 6600  2020-05-18               Anguilla       14987          NaN          3.0
# 6601  2020-05-18                Lesotho     2140235          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
df.shape
# Out:
# (6603, 9)

# %%
#checking the datatype of each column 
print(df.dtypes)

print(df.info())
# Out:
# Date                    object
# Country                 object
# Population               int64
# Total Tests            float64
# Total Cases            float64
# Total Deaths           float64
# Total Recovered        float64
# Serious or Critical    float64
# Active Cases           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6603 entries, 0 to 6602
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6603 non-null   object
#  1   Country              6603 non-null   object
#  2   Population           6603 non-null   int64
#  3   Total Tests          5505 non-null   float64
#  4   Total Cases          6554 non-null   float64
#  5   Total Deaths         5367 non-null   float64
#  6   Total Recovered      6318 non-null   float64
#  7   Serious or Critical  4117 non-null   float64
#  8   Active Cases         6544 non-null   float64
# ...

# %%
df1=pd.read_csv('population_structure_by_age_per_contry.csv')
df1
# Out:
#                    Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0                      USA                    0.189                     0.657
# 1                   Russia                    0.176                     0.682
# 2                    Spain                    0.147                     0.659
# 3                   Brazil                    0.217                     0.697
# 4                       UK                    0.177                     0.638
# ..                     ...                      ...                       ...
# 208              St. Barth                      NaN                       NaN
# 209         Western Sahara                      NaN                       NaN
# 210               Anguilla                      NaN                       NaN
# 211                Lesotho                    0.354                     0.601
# 212  Saint Pierre Miquelon                      NaN                       NaN
#
#      Fraction age 65+ years
# ...

# %%
df1.shape
# Out:
# (213, 4)

# %%
#checking the datatype of each column 
print(df1.dtypes)

print(df1.info())
# Out:
# Country                      object
# Fraction age 0-14 years     float64
# Fraction age 15-64 years    float64
# Fraction age 65+ years      float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   213 non-null    object
#  1   Fraction age 0-14 years   176 non-null    float64
#  2   Fraction age 15-64 years  176 non-null    float64
#  3   Fraction age 65+ years    176 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 6.8+ KB
# None

# %%
# Merging the both data set because total deaths is heavily depends on fraction age groups..this will help as to analysis the data better
df2=pd.merge(df,df1)
df2
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-19                    USA   330774664    3861549.0     763832.0
# 2     2020-04-20                    USA   330774664    4026360.0     792759.0
# 3     2020-04-21                    USA   330774664    4187392.0     818744.0
# 4     2020-04-22                    USA   330774664    4325342.0     848717.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-14  Saint Pierre Miquelon        5797          NaN          1.0
# 6599  2020-05-15  Saint Pierre Miquelon        5797          NaN          1.0
# 6600  2020-05-16  Saint Pierre Miquelon        5797          NaN          1.0
# 6601  2020-05-17  Saint Pierre Miquelon        5797          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
df2.head()
# Out:
#          Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0  2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1  2020-04-19     USA   330774664    3861549.0     763832.0       40553.0
# 2  2020-04-20     USA   330774664    4026360.0     792759.0       42514.0
# 3  2020-04-21     USA   330774664    4187392.0     818744.0       45318.0
# 4  2020-04-22     USA   330774664    4325342.0     848717.0       47659.0
#
#    Total Recovered  Serious or Critical  Active Cases  \
# 0          68269.0              13551.0      631509.0
# 1          71003.0              13566.0      652276.0
# 2          72389.0              13951.0      677856.0
# 3          82923.0              14016.0      690503.0
# 4          84050.0              14016.0      717008.0
#
#    Fraction age 0-14 years  Fraction age 15-64 years  Fraction age 65+ years
# 0                    0.189                     0.657                   0.154
# ...

# %%
#checking the datatype of each column 
print(df2.dtypes)

print(df2.info())
# Out:
# Date                         object
# Country                      object
# Population                    int64
# Total Tests                 float64
# Total Cases                 float64
# Total Deaths                float64
# Total Recovered             float64
# Serious or Critical         float64
# Active Cases                float64
# Fraction age 0-14 years     float64
# Fraction age 15-64 years    float64
# Fraction age 65+ years      float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6603 entries, 0 to 6602
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      6603 non-null   object
#  1   Country                   6603 non-null   object
#  2   Population                6603 non-null   int64
#  3   Total Tests               5505 non-null   float64
#  4   Total Cases               6554 non-null   float64
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df2.head(50)
# Out:
#           Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0   2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1   2020-04-19     USA   330774664    3861549.0     763832.0       40553.0
# 2   2020-04-20     USA   330774664    4026360.0     792759.0       42514.0
# 3   2020-04-21     USA   330774664    4187392.0     818744.0       45318.0
# 4   2020-04-22     USA   330774664    4325342.0     848717.0       47659.0
# 5   2020-04-23     USA   330774664    4696704.0     880204.0       49845.0
# 6   2020-04-24     USA   330774664    5015602.0     925038.0       52185.0
# 7   2020-04-25     USA   330774664    5279237.0     960651.0       54256.0
# 8   2020-04-26     USA   330774664    5470464.0     987160.0       55413.0
# 9   2020-04-27     USA   330774664    5696928.0    1010356.0       56797.0
# 10  2020-04-28     USA   330774664    5919847.0    1035765.0       59266.0
# ...

# %%
df2["Country"].value_counts()
# Out:
# Greece                 31
# Fiji                   31
# Syria                  31
# Norway                 31
# Albania                31
#                        ..
# Poland                 31
# El Salvador            31
# Antigua and Barbuda    31
# Finland                31
# Burundi                31
# Name: Country, Length: 213, dtype: int64

# %%
df2["Date"].value_counts()
# Out:
# 2020-04-29    213
# 2020-04-27    213
# 2020-05-10    213
# 2020-05-11    213
# 2020-05-07    213
# 2020-04-26    213
# 2020-05-03    213
# 2020-05-13    213
# 2020-05-05    213
# 2020-04-18    213
# 2020-04-25    213
# 2020-04-19    213
# 2020-04-20    213
# 2020-04-21    213
# 2020-05-01    213
# 2020-05-06    213
# 2020-04-23    213
# 2020-05-09    213
# 2020-04-22    213
# 2020-05-12    213
# 2020-05-04    213
# 2020-05-08    213
# 2020-04-30    213
# 2020-05-18    213
# 2020-05-15    213
# 2020-05-02    213
# 2020-05-16    213
# 2020-04-28    213
# 2020-05-14    213
# 2020-05-17    213
# 2020-04-24    213
# Name: Date, dtype: int64

# %%
#checking null values using heat map
sns.heatmap(df2.isnull())
#we can see that their is no null values

# %%
df2.isnull().sum()
# Out:
# Date                           0
# Country                        0
# Population                     0
# Total Tests                 1098
# Total Cases                   49
# Total Deaths                1236
# Total Recovered              285
# Serious or Critical         2486
# Active Cases                  59
# Fraction age 0-14 years     1147
# Fraction age 15-64 years    1147
# Fraction age 65+ years      1147
# dtype: int64

# %%
df2.dropna(how='any',inplace=True)

# %%
df2.shape
# Out:
# (3242, 12)

# %%
df2["Day"] = pd.to_datetime(df2.Date, format="%Y-%m-%d").dt.day

# %%
df2["Month"] = pd.to_datetime(df2.Date, format="%Y-%m-%d").dt.month

# %%
df2["Year"] = pd.to_datetime(df2.Date, format="%Y-%m-%d").dt.year

# %%
df2.dtypes
# Out:
# Date                         object
# Country                      object
# Population                    int64
# Total Tests                 float64
# Total Cases                 float64
# Total Deaths                float64
# Total Recovered             float64
# Serious or Critical         float64
# Active Cases                float64
# Fraction age 0-14 years     float64
# Fraction age 15-64 years    float64
# Fraction age 65+ years      float64
# Day                           int64
# Month                         int64
# Year                          int64
# dtype: object

# %% [markdown]
# # Data Analysis Through Visualization

# %%
sns.catplot(y = "Total Tests", x = 'Day', data = df2.sort_values("Total Tests", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Tests", x = 'Month', data = df2.sort_values("Total Tests", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Tests", x = 'Year', data = df2.sort_values("Total Tests", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Cases", x = 'Day', data = df2.sort_values("Total Cases", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Cases", x = 'Month', data = df2.sort_values("Total Cases", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Cases", x = 'Year', data = df2.sort_values("Total Cases", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Recovered", x = 'Day', data = df2.sort_values("Total Recovered", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Recovered", x = 'Month', data = df2.sort_values("Total Recovered", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Total Recovered", x = 'Year', data = df2.sort_values("Total Recovered", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
plt.subplots(nrows=1, ncols=1,figsize=(16, 4))
ax = sns.lvplot(x=df2['Month'], y=df['Total Deaths'], palette='coolwarm')
ax.set_title('Deaths')
# Out:
# Text(0.5, 1.0, 'Deaths')

# %%
plt.subplots(nrows=1, ncols=1,figsize=(16, 4))
ax = sns.lvplot(x=df2['Day'], y=df['Total Deaths'], palette='coolwarm')
ax.set_title('Deaths')
# Out:
# Text(0.5, 1.0, 'Deaths')

# %%
plt.subplots(nrows=1, ncols=1,figsize=(16, 4))
ax = sns.lvplot(x=df2['Year'], y=df['Total Deaths'], palette='coolwarm')
ax.set_title('Deaths')
# Out:
# Text(0.5, 1.0, 'Deaths')

# %%
# from below observation we can say that many outliers are present in Age,Fnlwgt,capital gain, capital loss and hours per week

df2.plot(kind='box',subplots=True,layout=(3,7),figsize=(20,20))
# Out:
# Population                     AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# Total Tests                 AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# Total Cases                 AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# Total Deaths                AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# Total Recovered             AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# Serious or Critical         AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# Active Cases                AxesSubplot(0.805488,0.657941;0.0945122x0.222059)
# Fraction age 0-14 years        AxesSubplot(0.125,0.391471;0.0945122x0.222059)
# Fraction age 15-64 years    AxesSubplot(0.238415,0.391471;0.0945122x0.222059)
# Fraction age 65+ years      AxesSubplot(0.351829,0.391471;0.0945122x0.222059)
# Day                         AxesSubplot(0.465244,0.391471;0.0945122x0.222059)
# Month                       AxesSubplot(0.578659,0.391471;0.0945122x0.222059)
# ...

# %%
for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# # Statistical Analysis

# %%
df2.describe()
# Out:
#          Population   Total Tests   Total Cases  Total Deaths  \
# count  3.242000e+03  3.242000e+03  3.242000e+03   3242.000000
# mean   3.281590e+07  3.322855e+05  3.041770e+04   1965.386181
# std    5.404282e+07  9.538617e+05  1.227912e+05   8057.354352
# min    9.783300e+04  7.300000e+01  1.700000e+01      0.000000
# 25%    4.262847e+06  2.223725e+04  9.112500e+02     14.000000
# 50%    1.019102e+07  8.469100e+04  3.570500e+03     89.000000
# 75%    3.770277e+07  2.325065e+05  1.421075e+04    405.000000
# max    3.307747e+08  1.230074e+07  1.550294e+06  91981.000000
#
#        Total Recovered  Serious or Critical  Active Cases  \
# count      3242.000000          3242.000000  3.242000e+03
# mean      10376.896669           467.561073  1.809725e+04
# std       31167.508787          1853.445360  9.112594e+04
# min           2.000000             1.000000  2.000000e+00
# 25%         272.250000             4.000000  4.262500e+02
# ...

# %% [markdown]
# -> From the above analysis we can see that their is lot of diff between 75% and maximun in total deaths, total recovered, serious or critical so many outies are present in the data set
#
# -> ANd their is a huge difference between maen and median in total deaths , total recovered and serious or critical

# %%
#Observing corelation between the columns through heatmap
plt.figure(figsize=(15,15))
sns.heatmap(df2.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# -> From the above analysis we can say that Total deaths is Highly positively co-related with Total tests,Total Cases,Total Recovered,Serious or critical and active cases

# %%
df.corr()
# Out:
#                      Population  Total Tests  Total Cases  Total Deaths  \
# Population             1.000000     0.307950     0.225890      0.177861
# Total Tests            0.307950     1.000000     0.900321      0.811128
# Total Cases            0.225890     0.900321     1.000000      0.934705
# Total Deaths           0.177861     0.811128     0.934705      1.000000
# Total Recovered        0.309692     0.825681     0.829137      0.840124
# Serious or Critical    0.231260     0.744832     0.890988      0.829517
# Active Cases           0.179400     0.859148     0.977766      0.892579
#
#                      Total Recovered  Serious or Critical  Active Cases
# Population                  0.309692             0.231260      0.179400
# Total Tests                 0.825681             0.744832      0.859148
# Total Cases                 0.829137             0.890988      0.977766
# Total Deaths                0.840124             0.829517      0.892579
# ...

# %%
# droping Patient ID column from  dataset
df2= df2.drop("Date",axis = 1)

# %% [markdown]
# # Label Encoding

# %%
#Using Label Encoder 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['Country']
for i in list1:
     df2[i]=le.fit_transform(df2[i].astype(str))

# %%
df2.dtypes
# Out:
# Country                       int32
# Population                    int64
# Total Tests                 float64
# Total Cases                 float64
# Total Deaths                float64
# Total Recovered             float64
# Serious or Critical         float64
# Active Cases                float64
# Fraction age 0-14 years     float64
# Fraction age 15-64 years    float64
# Fraction age 65+ years      float64
# Day                           int64
# Month                         int64
# Year                          int64
# dtype: object

# %%
df2
# Out:
#       Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0         109   330774664    3722145.0     738792.0       39014.0
# 1         109   330774664    3861549.0     763832.0       40553.0
# 2         109   330774664    4026360.0     792759.0       42514.0
# 3         109   330774664    4187392.0     818744.0       45318.0
# 4         109   330774664    4325342.0     848717.0       47659.0
# ...       ...         ...          ...          ...           ...
# 5840       15      396732        995.0         18.0           2.0
# 5841       15      396732       1043.0         18.0           2.0
# 5842       15      396732       1043.0         17.0           2.0
# 5843       15      396732       1043.0         18.0           2.0
# 5844       15      396732       1043.0         18.0           2.0
#
#       Total Recovered  Serious or Critical  Active Cases  \
# 0             68269.0              13551.0      631509.0
# ...

# %% [markdown]
# # Splitting the data into input and target

# %%
x=df2.drop(['Total Deaths'],axis=1)
y=df2["Total Deaths"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=scaler.fit_transform(x)

# %% [markdown]
# # Importing Necessary Libraries

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print("max r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %%
lreg=LinearRegression()
i=maxr2_score(lreg,x,y)
# Out:
# max r2 score corresponding to 80 is 0.9995758933354812

# %%
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Linear Regression: -53.613829283007945
# standard deviation in r2 score for Linear Regression 107.63623802412495

# %% [markdown]
# # Finding Best Parameters by Using GridSearchCV

# %%
knr=KNeighborsRegressor()
parameters={'n_neighbors':range(1,10),'algorithm':['auto', 'ball_tree', 'kd_tree']}
gd=GridSearchCV(knr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1],'selection' : ['cyclic', 'random']}
gd=GridSearchCV(lsreg,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

dtr=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae'),'max_features' : ['auto', 'sqrt', 'log2']}
gd=GridSearchCV(dtr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

enr=ElasticNet()
parametors={"alpha":[0.001,0.01,0.1,1]}
gd=GridSearchCV(enr,parametors)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

rfr=RandomForestRegressor()
parameters={"n_estimators":[10,50,100,120,150],"max_features": ["auto", "sqrt", "log2"]}
gd=GridSearchCV(rfr,parameters,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

svr=SVR()
parameters={"kernel" : ( "Linear" ,"rbf" ) ,"C": [1,10]}
gd=GridSearchCV(svr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,120,150]}
gd=GridSearchCV(gbr,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")
# Out:
# {'algorithm': 'auto', 'n_neighbors': 9}
#
#
# {'alpha': 0.1, 'selection': 'cyclic'}
#
#
# {'criterion': 'mse', 'max_features': 'auto'}
#
#
# {'alpha': 1}
#
#
# {'max_features': 'auto', 'n_estimators': 120}
#
#
# {'C': 10, 'kernel': 'rbf'}
#
#
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
knn=KNeighborsRegressor(algorithm='auto', n_neighbors=9)
i=maxr2_score(knn,x,y)
print("\n")

print("Mean r2 score for KNeighbor  Regression:",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNeighbor   Regression",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
print("\n___________________________________________________________________________________________________________\n")

lsreg=Lasso(alpha=0.1, selection='cyclic')
i=maxr2_score(lsreg,x,y)
print("\n")

print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
print("\n___________________________________________________________________________________________________________\n")


dtr=DecisionTreeRegressor(criterion = 'mse',max_features='auto')
i=maxr2_score(dtr,x,y)
print("\n")

print("Mean r2 score for DecisionTreeRegressor :",cross_val_score(dtr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for DecisionTreeRegressor",cross_val_score(dtr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")

enr=ElasticNet(alpha=1)
i=maxr2_score(enr,x,y)
print("\n")

print("Mean r2 score for Elastic net Regression:",cross_val_score(enr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Elastic net Regression",cross_val_score(enr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")



rfr=RandomForestRegressor(max_features='auto',n_estimators=120)
i=maxr2_score(rfr,x,y)
print("\n")

print("Mean r2 score for RandomForestRegressor :",cross_val_score(rfr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for RandomForestRegressor ",cross_val_score(rfr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=100)
i=maxr2_score(gbr,x,y)
print("\n")

print("Mean r2 score for gradient boosting Regression:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for gradient boosting Regression",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")


svr=SVR(C= 10, kernel= 'rbf')
i=maxr2_score(svr,x,y)
print("\n")

print("Mean r2 score for SVR:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for SVR",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
print("\n_____________________________________________________________________________________________________________\n")
# Out:
# max r2 score corresponding to 49 is 0.9977595157335557
#
#
# Mean r2 score for KNeighbor  Regression: -77.29662491944174
# standard deviation in r2 score for KNeighbor   Regression 110.1448733600496
#
# ___________________________________________________________________________________________________________
#
# max r2 score corresponding to 70 is 0.9828033873186944
#
#
# Mean r2 score for Lasso Regression: -282.52451263262776
# standard deviation in r2 score for Lasso Regression 475.0426243278408
#
# ___________________________________________________________________________________________________________
#
# max r2 score corresponding to 80 is 0.9995026031896802
#
#
# Mean r2 score for DecisionTreeRegressor : -2.944204351558832
# standard deviation in r2 score for DecisionTreeRegressor 4.888105032283448
#
# _____________________________________________________________________________________________________________
#
# max r2 score corresponding to 70 is 0.9241444464054895
#
#
# ...

# %% [markdown]
# # From the above analysis w.r.t r2_score Random Forest Regressor is performing best

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=60,test_size=0.20)
rfr=RandomForestRegressor(max_features='auto',n_estimators=120)
rfr.fit(x,y)
y_pred=rfr.predict(x_test)

# %%
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is:",r2_score(y_test,y_pred))
# Out:
# RMSE is:  45.35801089239212
# r2_score is: 0.9999656799884774

# %%
prediction = rfr.predict(x_test)

# %%
r2_score(y_test,prediction)
# Out:
# 0.9999656799884774

# %% [markdown]
# # Saving Model

# %%
import joblib
model=joblib.dump(rfr,"Covid-19_data-pred.pkl")
