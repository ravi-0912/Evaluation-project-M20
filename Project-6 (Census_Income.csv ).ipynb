# %%
#Importing Libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the data set
train=pd.read_csv('Census_income.csv',header=None)
test=pd.read_csv('Census_income-Test.csv' ,header=None)

# %%
df=pd.concat([train,test])
df
# Out:
#        0                  1       2           3   4                    5   \
# 0      39          State-gov   77516   Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2      38            Private  215646     HS-grad   9             Divorced
# 3      53            Private  234721        11th   7   Married-civ-spouse
# 4      28            Private  338409   Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...         ...  ..                  ...
# 16276  39            Private  215419   Bachelors  13             Divorced
# 16277  64                  ?  321403     HS-grad   9              Widowed
# 16278  38            Private  374983   Bachelors  13   Married-civ-spouse
# 16279  44            Private   83891   Bachelors  13             Divorced
# 16280  35       Self-emp-inc  182148   Bachelors  13   Married-civ-spouse
#
#                        6                7                    8        9   \
# ...

# %%
# Defining column names and replacing some special character columns names with proper names 
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'educational num','marital status', 'occupation', 'relationship',
                'race', 'gender','capital gain', 'capital loss','hours per week', 'country','income']

# %%
df
# Out:
#        age          workclass  fnlwgt   education  educational num  \
# 0       39          State-gov   77516   Bachelors               13
# 1       50   Self-emp-not-inc   83311   Bachelors               13
# 2       38            Private  215646     HS-grad                9
# 3       53            Private  234721        11th                7
# 4       28            Private  338409   Bachelors               13
# ...    ...                ...     ...         ...              ...
# 16276   39            Private  215419   Bachelors               13
# 16277   64                  ?  321403     HS-grad                9
# 16278   38            Private  374983   Bachelors               13
# 16279   44            Private   83891   Bachelors               13
# 16280   35       Self-emp-inc  182148   Bachelors               13
#
#             marital status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# ...

# %%
#checking the datatype of each column 
print(df.dtypes)
# Age,fnlwgt,Education num,capital gain ,capital loss,hours per week are of integer type
# Rest are object type data
print(df.info())
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational num     int64
# marital status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital gain        int64
# capital loss        int64
# hours per week      int64
# country            object
# income             object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48842 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational num  48842 non-null  int64
#  5   marital status   48842 non-null  object
#  6   occupation       48842 non-null  object
# ...

# %%
df.keys()
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational num',
#        'marital status', 'occupation', 'relationship', 'race', 'gender',
#        'capital gain', 'capital loss', 'hours per week', 'country', 'income'],
#       dtype='object')

# %%
#checking the shape of data set
df.shape
# Out:
# (48842, 15)

# %%
#checking null values using heat map
sns.heatmap(df.isnull())
#we can see that their is no null values present in the dataset

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational num    0
# marital status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital gain       0
# capital loss       0
# hours per week     0
# country            0
# income             0
# dtype: int64

# %%
df['income'].value_counts()
# Out:
#  <=50K     24720
#  <=50K.    12435
#  >50K       7841
#  >50K.      3846
# Name: income, dtype: int64

# %% [markdown]
# ->From the above outcome we can see that a extra dot is present
#
# ->So removing that extra dot and converting output into <=50k and >50k

# %%
df['income'] = df.income.str.rstrip('.').astype('category')

# %%
df['income'].value_counts()
# Out:
#  <=50K    37155
#  >50K     11687
# Name: income, dtype: int64

# %%
# Checking the unique values of Attributes
print('workclass',df.workclass.unique())
print('education',df.education.unique())
print('marital status',df['marital status'].unique())
print('occupation',df.occupation.unique())
print('relationship',df.relationship.unique())
print('race',df.race.unique())
print('gender',df.gender.unique())
print('country',df['country'].unique())
print('income',df.income.unique())
# Out:
# workclass [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# education [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# marital status [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# occupation [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# relationship [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# race [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# gender [' Male' ' Female']
# ...

# %% [markdown]
# -> We can see that workclass, occupation and country has a special character value '?'
#
# ->So we have to remove that special character value to get a better result

# %%
# Replacing special character to NaN
df['country'] = df['country'].replace(' ?',np.nan)
df['workclass'] = df['workclass'].replace(' ?',np.nan)
df['occupation'] = df['occupation'].replace(' ?',np.nan)

# %%
df.tail()
# Out:
#        age      workclass  fnlwgt   education  educational num  \
# 16276   39        Private  215419   Bachelors               13
# 16277   64            NaN  321403     HS-grad                9
# 16278   38        Private  374983   Bachelors               13
# 16279   44        Private   83891   Bachelors               13
# 16280   35   Self-emp-inc  182148   Bachelors               13
#
#             marital status        occupation     relationship  \
# 16276             Divorced    Prof-specialty    Not-in-family
# 16277              Widowed               NaN   Other-relative
# 16278   Married-civ-spouse    Prof-specialty          Husband
# 16279             Divorced      Adm-clerical        Own-child
# 16280   Married-civ-spouse   Exec-managerial          Husband
#
#                       race   gender  capital gain  capital loss  \
# 16276                White   Female             0             0
# 16277                Black     Male             0             0
# ...

# %%
#dropping the nan values 
df.dropna(how='any',inplace=True)

# %%
#Finding if special characters are present in the data 
df.isin([' ?']).sum(axis=0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational num    0
# marital status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital gain       0
# capital loss       0
# hours per week     0
# country            0
# income             0
# dtype: int64

# %%
df.shape
# Out:
# (45222, 15)

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.subplots(figsize=(10,10))
sns.countplot(df['workclass'])
plt.title("workclass")
# We can see that people working in private are more that 30000 and rest are below 5000
# Out:
# Text(0.5, 1.0, 'workclass')

# %%
plt.subplots(figsize=(10,10))
sns.countplot(df['relationship'])
plt.title("relationship")
# Out:
# Text(0.5, 1.0, 'relationship')

# %%
plt.subplots(figsize=(15,15))
sns.countplot(df['education'])
plt.title("Education")
# Out:
# Text(0.5, 1.0, 'Education')

# %%
plt.subplots(figsize=(20,20))
sns.countplot(df['occupation'])
plt.title("Occupation")
# Out:
# Text(0.5, 1.0, 'Occupation')

# %%
plt.subplots(figsize=(10,10))
sns.countplot(df['marital status'])
plt.title("Marital Status")
# Out:
# Text(0.5, 1.0, 'Marital Status')

# %%
sns.countplot(df['gender'])
plt.title("gender")
# Out:
# Text(0.5, 1.0, 'gender')

# %%
# checking wheather data is normally distributed or not
for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %%
# from below observation we can say that many outliers are present in Age,Fnlwgt,capital gain, capital loss and hours per week

df.plot(kind='box',subplots=True,layout=(3,7),figsize=(20,20))
# Out:
# age                   AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# fnlwgt             AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# educational num    AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# capital gain       AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# capital loss       AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# hours per week     AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# dtype: object

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DB2D5D5340>,
# ...
#       dtype=object)

# %%
sns.countplot(x="gender",hue="income",data=df)

# %%
plt.subplots(figsize=(20,20))
sns.countplot(x="occupation",hue="income",data=df)

# %%
plt.subplots(figsize=(10,10))
sns.countplot(x="race",hue="income",data=df)

# %%
plt.violinplot(df["hours per week"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1db3b19fb20>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1db3ad435b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1db3b19ff70>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1db3b19fd90>}

# %%
plt.violinplot(df["educational num"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1db3b1acc40>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1db3a9ceca0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1db3b1b90d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1db3b1b93a0>}

# %%
plt.subplots(figsize=(20,20))
sns.countplot(x="marital status",hue="income",data=df)
plt.title('Income on the basis Marital Status')
# Out:
# Text(0.5, 1.0, 'Income on the basis Marital Status')

# %%
sns.countplot(x="gender",hue="income",data=df)
plt.title('Income on the basis of Gender')
# Out:
# Text(0.5, 1.0, 'Income on the basis of Gender')

# %%
plt.subplots(figsize=(20,20))
sns.countplot(x="education",hue="income",data=df)
plt.title('Income on the basis education')
# Out:
# Text(0.5, 1.0, 'Income on the basis education')

# %%
sns.barplot(df["capital loss"])

# %%
sns.barplot(df["capital gain"])

# %%
sns.pairplot(df)

# %% [markdown]
# # Using Label encoder to convert object type data into integer

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
for i in df.columns:
    if df[i].dtypes =='object':
        df[i]=le.fit_transform(df[i])

# %%
le=LabelEncoder()
list1=["income"]
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#                 age     workclass        fnlwgt     education  \
# count  45222.000000  45222.000000  4.522200e+04  45222.000000
# mean      38.547941      2.204502  1.897347e+05     10.313321
# std       13.217870      0.958122  1.056392e+05      3.817014
# min       17.000000      0.000000  1.349200e+04      0.000000
# 25%       28.000000      2.000000  1.173882e+05      9.000000
# 50%       37.000000      2.000000  1.783160e+05     11.000000
# 75%       47.000000      2.000000  2.379260e+05     12.000000
# max       90.000000      6.000000  1.490400e+06     15.000000
#
#        educational num  marital status    occupation  relationship  \
# count     45222.000000    45222.000000  45222.000000  45222.000000
# mean         10.118460        2.585180      5.969572      1.412697
# std           2.552881        1.500458      4.026400      1.597227
# min           1.000000        0.000000      0.000000      0.000000
# 25%           9.000000        2.000000      2.000000      0.000000
# ...

# %% [markdown]
# -> From the above analysis we can say that their is a huge difference between min and max in capital gain and capital loss
#
# -> Because of this capital gain and capital loss will be very skewed

# %%
#Observing corelation between the columns through heatmap
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ->From the above observation we can see that Income is Negatively co-related with fnlwgt, marital status and relationship
#
# ->Rest are positively co-related with Income

# %%
df.corr()
# Out:
#                       age  workclass    fnlwgt  education  educational num  \
# age              1.000000   0.085892 -0.075792  -0.003511         0.037623
# workclass        0.085892   1.000000 -0.034970   0.017846         0.040779
# fnlwgt          -0.075792  -0.034970  1.000000  -0.025318        -0.041993
# education       -0.003511   0.017846 -0.025318   1.000000         0.347444
# educational num  0.037623   0.040779 -0.041993   0.347444         1.000000
# marital status  -0.271623  -0.033221  0.033096  -0.041520        -0.064986
# occupation      -0.004474   0.017508 -0.002036  -0.033499         0.089686
# relationship    -0.247564  -0.065049  0.009909  -0.013179        -0.088431
# race             0.023776   0.049765 -0.029188   0.011457         0.031655
# gender           0.082053   0.069638  0.027240  -0.027569         0.003417
# capital gain     0.079683   0.034543 -0.004110   0.029889         0.126907
# ...

# %% [markdown]
# # Removing Outliers

# %%
print("The shape before removing outliers and skewness",df.shape)
print("skewness before removing outliers")
print(df.skew())
from scipy.stats import zscore
z=np.abs(zscore(df))
df=df[(z<3).all(axis=1)]
print("new shape after removing outliers",df.shape)
print("skewness after removing outliers")
print(df.skew())
# Out:
# The shape before removing outliers and skewness (45222, 15)
# skewness before removing outliers
# age                 0.532816
# workclass           1.148956
# fnlwgt              1.447516
# education          -0.945670
# educational num    -0.310621
# marital status     -0.006803
# occupation          0.107142
# relationship        0.829174
# race               -2.518427
# gender             -0.747521
# capital gain       11.789002
# capital loss        4.516304
# hours per week      0.340545
# country            -4.217526
# income              1.168075
# dtype: float64
# new shape after removing outliers (38653, 15)
# skewness after removing outliers
# age                 0.455183
# workclass           1.181497
# fnlwgt              0.631305
# education          -0.967212
# educational num    -0.136818
# marital status     -0.037157
# occupation          0.120371
# relationship        0.797678
# race               -2.650131
# gender             -0.716333
# ...

# %% [markdown]
# # Spliting Data into Input and Output Variable

# %%
x=df.drop('income',axis=1)
y=df['income']

# %%
x.head()
# Out:
#    age  workclass  fnlwgt  education  educational num  marital status  \
# 0   39          5   77516          9               13               4
# 1   50          4   83311          9               13               2
# 2   38          2  215646         11                9               0
# 3   53          2  234721          1                7               2
# 5   37          2  284582         12               14               2
#
#    occupation  relationship  race  gender  capital gain  capital loss  \
# 0           0             1     4       1          2174             0
# 1           3             0     4       1             0             0
# 2           5             1     4       1             0             0
# 3           5             0     2       1             0             0
# 5           3             5     4       0             0             0
#
#    hours per week  country
# 0              40       38
# 1              13       38
# 2              40       38
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 5    0
# Name: income, dtype: int32

# %%
print(x.shape)
print(y.shape)
# Out:
# (38653, 14)
# (38653,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (38653, 1)

# %%
# Converting particular cloumns in between 0 to 1 by using MinMax scaler
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
columns_to_scale=['age','educational num','capital gain','capital loss','hours per week']
x[columns_to_scale]=scaler.fit_transform(x[columns_to_scale])

# %%
#Reducing skewness of the data set
for i in x.columns:
    if x.skew().loc[i]>0.55:
        x[i]=np.log1p(x[i])

# %%
x.skew()
# Out:
# age                 0.455183
# workclass          -0.866179
# fnlwgt             -0.941211
# education          -0.967212
# educational num    -0.136818
# marital status     -0.037157
# occupation          0.120371
# relationship        0.293897
# race               -2.650131
# gender             -0.716333
# capital gain        4.018069
# capital loss       27.743142
# hours per week     -0.286828
# country            -5.413891
# dtype: float64

# %% [markdown]
# # Importing Necessary libraries

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,roc_auc_score,roc_curve,auc
from sklearn.model_selection import GridSearchCV

# %%
def max_acc_score(clf,x,y):
    max_acc_score=0
    for i in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        clf.fit(x_train,y_train)
        pred=clf.predict(x_test)
        acc_score=accuracy_score(pred,y_test)
        
        if acc_score>max_acc_score:
            max_acc_score=acc_score
            final_i=i
    print("max acc score corresponding to",final_i,"is",max_acc_score)
    return final_i

# %%
lg=LogisticRegression()
max_acc_score(lg,x,y)
# Out:
# max acc score corresponding to 63 is 0.8335273573923166
# 63

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=63,test_size=0.25)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (28989, 14)
# (28989, 1)
# (9664, 14)
# (9664, 1)

# %% [markdown]
# # Using GridSearchCV to find best parameters

# %%
lg=LogisticRegression()
parameters={'penalty':['l1','l2']}
gd=GridSearchCV(lg,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")


knc=KNeighborsClassifier()
parameters={'n_neighbors':range(1,10)}
gd=GridSearchCV(knc,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")



svc=SVC()
parameters={'kernel':('linear', 'poly', 'rbf'),'C':[1,10]}
gd=GridSearchCV(svc,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")



dtc=DecisionTreeClassifier()
parameters={'criterion':('gini','entropy')}
gd=GridSearchCV(dtc,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")



gbc=GradientBoostingClassifier()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,120,150]}
gd=GridSearchCV(gbc,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")



rfc=RandomForestClassifier()
parameters={"n_estimators":[10,50,100,120,150],"max_features": ["auto", "sqrt", "log2"]}
gd=GridSearchCV(gbc,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
print("\n")


ada=AdaBoostClassifier()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,120,150,200]}
gd=GridSearchCV(ada,parameters)
gd.fit(x_train,y_train)
print(gd.best_params_)
# Out:
# {'penalty': 'l2'}
#
#
# {'n_neighbors': 8}
#
#
# {'C': 10, 'kernel': 'poly'}
#
#
# {'criterion': 'entropy'}
#
#
# {'learning_rate': 0.1, 'n_estimators': 150}
#
#
# {'max_features': 'auto', 'n_estimators': 150}
#
#
# {'learning_rate': 1, 'n_estimators': 200}

# %%
model=[]
score=[]
cvs=[]
rocscore=[]

for i in [LogisticRegression(penalty='l2'),KNeighborsClassifier(n_neighbors=8),SVC(C=10,kernel='poly'),
          DecisionTreeClassifier(criterion='entropy'),GradientBoostingClassifier(learning_rate=0.1,n_estimators=150),
          RandomForestClassifier(max_features='auto',n_estimators=150),
          AdaBoostClassifier(learning_rate =1, n_estimators = 200),GaussianNB()]:
    k=i
    model.append(i)
    print("\n")
    print("The model score for",i,"are:")
    k.fit(x_train,y_train)
    k.score(x_train,y_train)
    predict=k.predict(x_test)
    print(predict)
    AS=accuracy_score(predict,y_test)
    print("Accuracy score =", AS)
    score.append(AS)
    cv_score=cross_val_score(k,x,y,cv=5,scoring="accuracy").mean()
    print("The cv score is",cv_score)
    cvs.append(cv_score)
    print("")
    cm=confusion_matrix(predict,y_test)
    print(cm)
    print("")
    print(classification_report(predict,y_test))
    print("\n")
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,predict)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score',roc_auc)
    rocscore.append(roc_auc)
    print("\n")
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
   
    plt.title(i)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC = %0.2f'%roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
# Out:
# The model score for LogisticRegression() are:
# [0 1 0 ... 0 0 0]
# Accuracy score = 0.8364031456953642
# The cv score is 0.8220318962500898
#
# [[7090 1179]
#  [ 402  993]]
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90      8269
#            1       0.46      0.71      0.56      1395
#
#     accuracy                           0.84      9664
#    macro avg       0.70      0.78      0.73      9664
# weighted avg       0.88      0.84      0.85      9664
#
#
#
# roc_auc_score 0.7017625430293233
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
# The model score for KNeighborsClassifier(n_neighbors=8) are:
# [0 1 0 ... 0 0 0]
# Accuracy score = 0.8334023178807947
# The cv score is 0.8281632907819076
#
# [[6985 1103]
#  [ 507 1069]]
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.90      8088
#            1       0.49      0.68      0.57      1576
#
# ...

# %% [markdown]
# # From below DataFrame we can see that Random Forest Classifier is the best Performing Model

# %%
result=pd.DataFrame({'Model':['LogisticRegression','KNeighborsClassifier','SVC','GaussianNB','DecisionTreeClassifier','GradientBoostingClassifier','RandomForestClassifier','AdaBoostClassifier'],'Accuracy_Score':score,'Cross_val_score':cvs,'Roc_auc_curve':rocscore})
result
# Out:
#                         Model  Accuracy_Score  Cross_val_score  Roc_auc_curve
# 0          LogisticRegression        0.836403         0.822032       0.701763
# 1        KNeighborsClassifier        0.833402         0.828163       0.712250
# 2                         SVC        0.832161         0.824153       0.649333
# 3                  GaussianNB        0.812086         0.805500       0.744600
# 4      DecisionTreeClassifier        0.868895         0.862727       0.775681
# 5  GradientBoostingClassifier        0.855339         0.847903       0.772496
# 6      RandomForestClassifier        0.867239         0.861589       0.777719
# 7          AdaBoostClassifier        0.771627         0.767496       0.778497

# %%
rfc=RandomForestClassifier(max_features='auto',n_estimators=150)
rfc.fit(x_train,y_train)
predict=rfc.predict(x_test)
AS=accuracy_score(predict,y_test)
print("Accuracy Score =",AS)
cv_score=cross_val_score(k,x,y,cv=5,scoring="accuracy").mean()
print("The CV Score =",cv_score)
false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,predict)
roc_auc=auc(false_positive_rate,true_positive_rate)
print('roc_auc_score',roc_auc)
# Out:
# Accuracy Score = 0.8539942052980133
# The CV Score = 0.7674956907248134
# roc_auc_score 0.7690129139590517

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(rfc,"Census_Income-Data.pkl")
# Out:
# ['Census_Income-Data.pkl']
